# %%
from container_rl.env.container import (
    ACTION_BUY_FACTORY,
    ACTION_BUY_FROM_FACTORY_STORE,
    ACTION_BUY_WAREHOUSE,
    ACTION_DOMESTIC_SALE,
    ACTION_MOVE_AUCTION,
    ACTION_MOVE_LOAD,
    ACTION_MOVE_SEA,
    ACTION_PASS,
    ACTION_PRODUCE,
    ACTION_REPAY_LOAN,
    ACTION_TAKE_LOAN,
    HEAD_ACTION_TYPE,
    HEAD_COLOR,
    HEAD_OPPONENT,
    HEAD_PRICE_SLOT,
    HEAD_PURCHASE,
    INITIAL_CASH,
    LEAVE_IDLE,
    LOAN_AMOUNT,
    LOCATION_AUCTION_ISLAND,
    LOCATION_HARBOUR_OFFSET,
    LOCATION_OPEN_SEA,
    MAX_WAREHOUSES_PER_PLAYER,
    NO_OP,
    PRICE_SLOTS,
    PRODUCE_CHOICES,
    PURCHASE_STOP,
    SHIP_CAPACITY,
    ContainerFunctional,
    ContainerJaxEnv,
    ContainerParams,
    EnvState,
    num_heads,
)

# %%
env_foundational = ContainerFunctional(num_players=3, num_colors=5)

# %%
env = ContainerJaxEnv(num_players=3)

# %%
dir(env)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_ezpickle_args',
#  '_ezpickle_kwargs',
#  '_np_random',
#  '_np_random_seed',
#  'action_space',
#  'close',
#  'func_env',
#  'get_wrapper_attr',
#  'has_wrapper_attr',
#  'metadata',
#  'np_random',
#  'np_random_seed',
#  'observation_space',
#  'render',
#  'render_mode',
#  'render_state',
#  'reset',
#  'rng',
#  'set_wrapper_attr',
#  'spec',
#  'step',
# ...

# %%
print(env.action_space)
# Out:
# MultiDiscrete([12  3  6 11 32])

# %%
print(env.observation_space)
# Out:
# Box(0.0, 100.0, (448,), float32)

# %%
obs, _ = env.reset()

# %%
# buy factory
action = [1, 0, 1, 0, 31]
obs, rew, terminated, truncated, _ = env.step(action)
# Out:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Cell In[8], line 3
#       1 # buy factory
#       2 action = [1, 0, 1, 0, 31]
# ----> 3 obs, rew, terminated, truncated, _ = env.step(action)
#
# File /guy/code/container-rl/.venv/lib/python3.13/site-packages/gymnasium/envs/functional_jax_env.py:78, in FunctionalJaxEnv.step(self, action)
#      75 """Steps through the environment using the action."""
#      76 rng, self.rng = jrng.split(self.rng)
# ---> 78 next_state = self.func_env.transition(self.state, action, rng)
#      79 observation = self.func_env.observation(next_state, rng)
#      80 reward = self.func_env.reward(self.state, action, next_state, rng)
#
#     [... skipping hidden 5 frame]
#
# File /guy/code/container-rl/container_rl/env/container.py:539, in ContainerFunctional.transition(self, state, action, key, params)
#     536 def _do_auction_continue(s):
# ...
